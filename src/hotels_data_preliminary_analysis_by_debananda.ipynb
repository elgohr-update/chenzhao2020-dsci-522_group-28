# %% [markdown]
# # Hotels Data - Preliminary analysis
# - Prepared by: Debananda Sarkar
# - Created on: 2020-11-21

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import altair as alt
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Import Data

# %%
hotels_df = pd.read_csv("../data/raw/hotels_dataset.csv")

# %% [markdown]
# ## Setting global seed

# %%
seed = 2020

# %% [markdown]
# ## Splitting training and test data

# %%
train_df, test_df = train_test_split(hotels_df, test_size=0.2, random_state=seed)

# %% [markdown]
# ## Checking class imbalance

# %%
class_dist = train_df.value_counts("is_canceled").reset_index(name="count")
class_dist["perc"] = np.round(class_dist["count"]/train_df.shape[0] * 100, 2)
class_dist
# Out:
#    is_canceled  count   perc
# 0            0  60105  62.93
# 1            1  35407  37.07

# %%
class_dist_plot = alt.Chart(class_dist, title="Class Distribution").mark_bar().encode(
    x = alt.X("perc", scale=alt.Scale(domain= (0, 100)), title = "Percentage of observations"),
    y = alt.Y("is_canceled:N", title="Class value"),
    text = "perc"
)
class_dist_plot + class_dist_plot.mark_text(dx = 18)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Observations
#
# - We have a class imbalance between positive (where booking was canceled) and negative (where booking was not canceled) class
# - We would like to predict the cancellation as accurately as possible, so that the hotel does not get a unwanted surprise. Hence, we would like to maximize recall
# - However, in the process of maximizing recall we might over predict cancellation. That will be an adverse scenario as the management may get into panic and start introducing promotions which might take a toll of hotel revenue. Hence, we would like to keep the precision high as well.
# - As we are interested in keeping both precision and recall high, **f1-score** will be a good evaluation metric here.

# %% [markdown]
# ## Checking correlation among all variables

# %%
corr_df = train_df.corr().stack().reset_index(name="corr")
corr_df["round_corr"] = np.round(corr_df["corr"], 2)
corr_plot = (
    alt.Chart(corr_df, title="Feature Correlation")
    .mark_rect()
    .encode(
        x="level_0",
        y="level_1",
        tooltip="corr",
        color=alt.Color("corr", scale=alt.Scale(domain=(-1, 1), scheme="purpleorange"))
    )
    .properties(width=500, height=500)
)
corr_plot

corr_text = (
    alt.Chart(corr_df)
    .mark_text(size=8)
    .encode(
        x="level_0",
        y="level_1",
        text="round_corr",
    )
    .properties(width=500, height=500)
)
corr_plot + corr_text
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Observations:
#
# - We have moderate correlation between
#     - `arrival_date_week_number` and `arrival_date_year`
#     - `stay_in_week_nights` and `stay_in_weekend_nights`
#
# - We need to explore these relation further

# %% [markdown]
# ## Correlation with target

# %%
corr_plot = (
    alt.Chart(corr_df[corr_df.level_1 == "is_canceled"], title="Feature Correlation")
    .mark_rect()
    .encode(
        x="level_0",
        y="level_1",
        tooltip="corr",
        color=alt.Color("corr", scale=alt.Scale(domain=(-1, 1), scheme="purpleorange"))
    )
    .properties(width=600)
)
corr_plot

corr_text = (
    alt.Chart(corr_df[corr_df.level_1 == "is_canceled"])
    .mark_text(size=8)
    .encode(
        x="level_0",
        y="level_1",
        text="round_corr",
    )
    .properties(width=600)
)
corr_plot + corr_text
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Observation
#
# - `lead_time` and `total_of_special_requests` have some correlation with the target.

# %% [markdown]
# ## Checking null values

# %%
null_df = train_df.isna().sum().reset_index(name="count_of_nulls").query("count_of_nulls != 0")
null_df["perc"] = np.round(null_df["count_of_nulls"] / train_df.shape[0] * 100, 2)
null_df
# Out:
#        index  count_of_nulls   perc
# 10  children               4   0.00
# 13   country             383   0.40
# 23     agent           13101  13.72
# 24   company           90071  94.30

# %% [markdown]
# ### Observation
#
# - We can drop `company` as 94% values are null

# %% [markdown]
# ## Feature Categorization

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95512 entries, 74159 to 41824
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           95512 non-null  object
#  1   is_canceled                     95512 non-null  int64
#  2   lead_time                       95512 non-null  int64
#  3   arrival_date_year               95512 non-null  int64
#  4   arrival_date_month              95512 non-null  object
#  5   arrival_date_week_number        95512 non-null  int64
#  6   arrival_date_day_of_month       95512 non-null  int64
#  7   stays_in_weekend_nights         95512 non-null  int64
#  8   stays_in_week_nights            95512 non-null  int64
#  9   adults                          95512 non-null  int64
#  10  children                        95508 non-null  float64
#  11  babies                          95512 non-null  int64
#  12  meal                            95512 non-null  object
#  13  country                         95129 non-null  object
#  14  market_segment                  95512 non-null  object
#  15  distribution_channel            95512 non-null  object
#  16  is_repeated_guest               95512 non-null  int64
#  17  previous_cancellations          95512 non-null  int64
#  18  previous_bookings_not_canceled  95512 non-null  int64
#  19  reserved_room_type              95512 non-null  object
#  20  assigned_room_type              95512 non-null  object
#  21  booking_changes                 95512 non-null  int64
#  22  deposit_type                    95512 non-null  object
#  23  agent                           82411 non-null  float64
#  24  company                         5441 non-null   float64
#  25  days_in_waiting_list            95512 non-null  int64
#  26  customer_type                   95512 non-null  object
#  27  adr                             95512 non-null  float64
#  28  required_car_parking_spaces     95512 non-null  int64
#  29  total_of_special_requests       95512 non-null  int64
#  30  reservation_status              95512 non-null  object
#  31  reservation_status_date         95512 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 24.0+ MB

# %%
train_df.head(10).T
# Out:
#                                      74159       59282       56463  \
# hotel                           City Hotel  City Hotel  City Hotel
# is_canceled                              1           1           1
# lead_time                              349         254         174
# arrival_date_year                     2015        2016        2016
# arrival_date_month                 October     October   September
# arrival_date_week_number                40          44          37
# arrival_date_day_of_month                1          25           7
# stays_in_weekend_nights                  0           0           0
# stays_in_week_nights                     2           5           1
# adults                                   2           2           2
# children                                 0           0           0
# babies                                   0           0           0
# meal                                    BB          BB          BB
# country                                PRT         DEU         BEL
# market_segment                      Groups   Online TA   Online TA
# distribution_channel                 TA/TO       TA/TO       TA/TO
# is_repeated_guest                        0           0           0
# previous_cancellations                   1           0           0
# previous_bookings_not_canceled           0           0           0
# reserved_room_type                       A           A           A
# assigned_room_type                       A           A           A
# booking_changes                          0           0           0
# deposit_type                    Non Refund  No Deposit  No Deposit
# agent                                    1           9           9
# company                                NaN         NaN         NaN
# days_in_waiting_list                     0           0           0
# customer_type                     Contract   Transient   Transient
# adr                                     62       90.95       126.9
# required_car_parking_spaces              0           0           0
# total_of_special_requests                0           0           2
# reservation_status                Canceled    Canceled    Canceled
# reservation_status_date         2015-01-01  2016-02-17  2016-08-24
#
#                                      94823         247           35268  \
# hotel                           City Hotel  Resort Hotel  Resort Hotel
# is_canceled                              0             1             0
# lead_time                              169            69            68
# arrival_date_year                     2016          2015          2017
# arrival_date_month                  August          July         April
# arrival_date_week_number                32            28            15
# arrival_date_day_of_month                5             9            13
# stays_in_weekend_nights                  2             2             1
# stays_in_week_nights                     4             6             3
# adults                                   2             2             2
# children                                 0             0             0
# babies                                   0             0             0
# meal                                    BB            HB            BB
# country                                DEU           PRT           NZL
# market_segment                   Online TA     Online TA     Online TA
# distribution_channel                 TA/TO         TA/TO         TA/TO
# is_repeated_guest                        0             0             0
# previous_cancellations                   0             0             0
# previous_bookings_not_canceled           0             0             0
# reserved_room_type                       A             A             A
# assigned_room_type                       A             A             A
# booking_changes                          0             0             0
# deposit_type                    No Deposit    No Deposit    No Deposit
# agent                                    9           240           240
# company                                NaN           NaN           NaN
# days_in_waiting_list                     0             0             0
# customer_type                    Transient     Transient     Transient
# adr                                  99.45        118.13         85.75
# required_car_parking_spaces              0             0             1
# total_of_special_requests                1             2             1
# reservation_status               Check-Out      Canceled     Check-Out
# reservation_status_date         2016-08-11    2015-05-13    2017-04-17
#
#                                        16557            4757          1445   \
# hotel                           Resort Hotel     Resort Hotel  Resort Hotel
# is_canceled                                1                0             0
# lead_time                                247              169             2
# arrival_date_year                       2015             2016          2015
# arrival_date_month                   October            March        August
# arrival_date_week_number                  41               14            36
# arrival_date_day_of_month                  9               31            30
# stays_in_weekend_nights                    1                0             1
# stays_in_week_nights                       2                3             0
# adults                                     2                2             2
# children                                   0                0             0
# babies                                     0                0             0
# meal                                      FB               BB            BB
# country                                  ESP              GBR           PRT
# market_segment                        Groups           Groups        Direct
# distribution_channel                   TA/TO           Direct        Direct
# is_repeated_guest                          0                0             0
# previous_cancellations                     1                0             0
# previous_bookings_not_canceled             0                0             0
# reserved_room_type                         A                A             A
# assigned_room_type                         A                D             D
# booking_changes                            0                1             0
# deposit_type                      Non Refund       Refundable    No Deposit
# agent                                     68              NaN           NaN
# company                                  NaN              223           NaN
# days_in_waiting_list                       0                0             0
# customer_type                      Transient  Transient-Party     Transient
# adr                                       81               66           154
# required_car_parking_spaces                0                0             1
# total_of_special_requests                  0                0             0
# reservation_status                  Canceled        Check-Out     Check-Out
# reservation_status_date           2015-09-02       2016-04-03    2015-08-31
#
#                                      86090
# hotel                           City Hotel
# is_canceled                              0
# lead_time                              156
# arrival_date_year                     2016
# arrival_date_month                   March
# arrival_date_week_number                13
# arrival_date_day_of_month               23
# stays_in_weekend_nights                  0
# stays_in_week_nights                     4
# adults                                   2
# children                                 0
# babies                                   0
# meal                                    BB
# country                                GBR
# market_segment                   Online TA
# distribution_channel                 TA/TO
# is_repeated_guest                        0
# previous_cancellations                   0
# previous_bookings_not_canceled           0
# reserved_room_type                       A
# assigned_room_type                       A
# booking_changes                          0
# deposit_type                    No Deposit
# agent                                   89
# company                                NaN
# days_in_waiting_list                     0
# customer_type                    Transient
# adr                                     14
# required_car_parking_spaces              0
# total_of_special_requests                0
# reservation_status               Check-Out
# reservation_status_date         2016-03-27

# %%
numeric_features = [
    "lead_time",
    "stays_in_weekend_nights",
    "stays_in_week_nights",
    "adults",
    "children",
    "babies",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "adr",
    "required_car_parking_spaces",
    "total_of_special_requests"
]
categorical_features = [
    "hotel",
    "arrival_date_month",
    "meal",
    "country",
    "market_segment",
    "distribution_channel",
    "reserved_room_type",
    "deposit_type",
    "customer_type"
]
drop_features = ["company", "reservation_status", "reservation_status_date"]
remainder_feature = [
    "arrival_date_year",
    "arrival_date_week_number",
    "arrival_date_day_of_month",
    "agent"
]
binary_features = ["is_repeated_guest"]
